# %%
import requests
import pandas as pd
import time      
import os   
import bs4
from bs4 import BeautifulSoup  
import io
import numpy as np
import requests
import urllib.request 
import json
from pandas import json_normalize

# %%
# load the csv of stocks market

readDfStocks= pd.read_csv(***) #local path to thw s&p stocks names that saved in csv ---- check the reademe file

# %%
# configuration of api key

keyToGoogleFApi = ***
keyToGoogleFApi_2=***

# %%
#configuration of the date

dayOfOpen="2021-12-01"
dayOfClose="2021-11-30"

# %%
#make a list of stocks name

stockList  = readDfStocks['tickName']

# %%
# initialization the first DF

url = r'https://api.polygon.io/v1/open-close/'+stockList[0]+'/'+dayOfOpen+'?adjusted=true&apiKey='+keyToGoogleFApi
urlData = requests.get(url).content
info = json.loads(urlData)
df = json_normalize(info)
df
# Out:
#   status        from symbol    open    high    low   close   volume  \
# 0     OK  2021-12-01    MMM  172.55  174.65  170.7  170.73  3255617
#
#    afterHours  preMarket
# 0       170.9     172.33

# %%
# initialization the second DF
    
url = r'https://api.polygon.io/v1/open-close/'+stockList[0]+'/'+dayOfClose+'?adjusted=true&apiKey='+keyToGoogleFApi
urlData = requests.get(url).content
info = json.loads(urlData)
df_2 = json_normalize(info)
df_2
# Out:
#   status        from symbol   open    high     low   close   volume  \
# 0     OK  2021-11-30    MMM  174.7  175.86  169.94  170.04  5340338
#
#    afterHours  preMarket
# 0         171        175

# %%
# sleep if there is more than 5 get req in one minute

def checkIfIs5(flagnumber):
    if flagnumber % 5 == 0:
        time.sleep(70)

# %%
    rageOfStocksIndex = range(1, 500)
    flagOfItera=0
    for row in rageOfStocksIndex:
        checkIfIs5(flagOfItera)
        flagOfItera += 1
        url = r'https://api.polygon.io/v1/open-close/'+stockList[row]+'/'+dayOfOpen+'?adjusted=true&apiKey='+keyToGoogleFApi
        urlData2 = requests.get(url).content
        info_ = json.loads(urlData2)
        df2 = json_normalize(info_)
        df = df.append(df2)

# %%
    rageOfstocks_2= range(1, 500)
    flagOfItera2=0
    for row2 in rageOfstocks_2:
        checkIfIs5(flagOfItera2)
        flagOfItera2 += 1
        url = r'https://api.polygon.io/v1/open-close/'+stockList[row2]+'/2021-11-30?adjusted=true&apiKey='+keyToGoogleFApi
        urlData2 = requests.get(url).content
        info_ = json.loads(urlData2)
        df2_1 = json_normalize(info_)
        df_2 = df_2.append(df2_1)

# %%
# set indexes to the dataframe
df['new_col'] = range(1, len(df) + 1)
df = df.reset_index()

# %%
# set indexes to the secoud dataframe
df_2['new_col'] = range(1, len(df_2) + 1)
df_2 = df_2.reset_index()

# %%
copydf= df.copy()
symbolList=list()
openlList=list()
closelList=list()
precentlList=list()
openDate =list()
closeDate =list()
precent = 1.03
for i in range(0,499):
    
    if ((copydf.iloc[i]['open']))>((df_2.iloc[i]['close'])*precent):
        #print(copydf.iloc[i]['open'] , df_2.iloc[i]['close'],"------", copydf.iloc[i]['symbol'])
        symbolList.append(copydf.iloc[i]['symbol'])
        openlList.append(copydf.iloc[i]['open'])
        openDate.append(copydf.iloc[i]['from'])
        closelList.append(df_2.iloc[i]['close'])
        closeDate.append(df_2.iloc[i]['from'])
        precentlList.append(((copydf.iloc[i]['open']-(df_2.iloc[i]['close']))/df_2.iloc[i]['close'])*100)
        

finaldf = pd.DataFrame(list(zip(symbolList, openlList,openDate,closelList,closeDate,precentlList)),
               columns =['Symbol', 'Open','openDate','Close','closeDate','precent-Cahge'])

finaldf
# Out:
#    Symbol     Open    openDate   Close   closeDate  precent-Cahge
# 0     APA   26.855  2021-12-01   25.77  2021-11-30       4.210322
# 1     BKR   24.240  2021-12-01   23.34  2021-11-30       3.856041
# 2     DVN   43.940  2021-12-01   42.06  2021-11-30       4.469805
# 3     HAL   22.250  2021-12-01   21.59  2021-11-30       3.056971
# 4     HES   76.860  2021-12-01   74.52  2021-11-30       3.140097
# 5     LEN  109.230  2021-12-01  105.05  2021-11-30       3.979058
# 6     LNC   68.440  2021-12-01   66.33  2021-11-30       3.181064
# 7     MRO   16.065  2021-12-01   15.49  2021-11-30       3.712072
# 8      MU   86.550  2021-12-01   84.00  2021-11-30       3.035714
# 9     OXY   30.690  2021-12-01   29.65  2021-11-30       3.507589
# 10    PSX   71.400  2021-12-01   69.17  2021-11-30       3.223941
# 11    PVH  110.570  2021-12-01  106.78  2021-11-30       3.549354
# 12    SLB   29.580  2021-12-01   28.68  2021-11-30       3.138075
# 13    URI  348.950  2021-12-01  338.74  2021-11-30       3.014111
# 14    VLO   68.990  2021-12-01   66.94  2021-11-30       3.062444
# 15   VRTX  195.590  2021-12-01  186.94  2021-11-30       4.627153
# 16    VNO   41.420  2021-12-01   40.14  2021-11-30       3.188839
